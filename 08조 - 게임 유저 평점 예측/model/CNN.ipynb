# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import torch.nn as nn
import torch
from torch.utils import data
import torch.optim as optim
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
import nltk
warnings.filterwarnings(action='ignore')

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.10.2  Device: cpu

# %%
df_game=pd.read_csv("../data/all_game.csv")
df_game_s=df_game[['title','userscore','summary']]
df_game_s
# Out:
#                                                 title  userscore  \
# 0               Surgeon Simulator: Experience Reality       4.40
# 1                Transformers: Rise of the Dark Spark       4.20
# 2                                         NBA Live 14       2.60
# 3                                            WWE 2K20       1.60
# 4                                            VR Karts       5.60
# ...                                               ...        ...
# 14350                                         Road 96       6.70
# 14351              WRC 9 FIA World Rally Championship       6.00
# 14352                                Shadow Warrior 3       6.00
# 14353  Blast Brigade vs. the Evil Legion of Dr. Cread       6.53
# 14354             Taiko no Tatsujin: The Drum Master!       8.00
#
#                                                  summary
# 0      This game is ridiculously fun once you ve plac...
# 1      Fight your way through both Earth and Cybertro...
# 2      BounceTek    Revolutionary physics based dribb...
# 3      F the haters  This game is still fun   And it ...
# 4      The checkered flag is about to drop on a new V...
# ...                                                  ...
# 14350   Summer 1996  Today is the day  You hit the ro...
# 14351   The game runs nicely 60fps xbox series S  The...
# 14352  Shadow Warrior 3 launches the offbeat first pe...
# 14353   Blast Brigade vs  The Evil Legion of Dr  Crea...
# 14354   The same fun drumming game you know and love ...
#
# [14355 rows x 3 columns]

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sj\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
stopwords=nltk.corpus.stopwords.words('english')
df_game_s['token_summary'] = df_game_s['summary'].apply(nltk.word_tokenize)
df_game_s['token_summary'] = df_game_s['token_summary'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
positive_summary=np.hstack(df_game_s[df_game_s.userscore>=df_game_s['userscore'].describe()['25%']]['token_summary'].values)
negative_summary=np.hstack(df_game_s[df_game_s.userscore<=df_game_s['userscore'].describe()['25%']]['token_summary'].values)

# %% [markdown]
# summary 칼럼을 토큰화하고 하위 25프로의 유저평점과 나머지를 분리해서 단어들을 알아본다.

# %%
dic_pos={}
for x in np.unique(positive_summary):
    dic_pos[x]=0
for x in positive_summary:
    dic_pos[x]+=1
dic_pos = dict(sorted(dic_pos.items(),reverse=True,key=lambda item: item[1]))

# %%
dic_neg={}
for x in np.unique(negative_summary):
    dic_neg[x]=0
for x in negative_summary:
    dic_neg[x]+=1
dic_neg = dict(sorted(dic_neg.items(),reverse=True,key=lambda item: item[1]))

# %% [markdown]
# 긍정적인 단어 빈도수

# %%
dic_pos
# Out:
# {'game': 8503,
#  'The': 5616,
#  'new': 3988,
#  'I': 3873,
#  'world': 2984,
#  'players': 1838,
#  'one': 1809,
#  'time': 1687,
#  'play': 1642,
#  'story': 1580,
#  'like': 1544,
#  'It': 1441,
#  'action': 1438,
#  'A': 1408,
#  'games': 1373,
#  'In': 1346,
#  'You': 1303,
#  'adventure': 1266,
#  'player': 1246,
#  'gameplay': 1206,
#  'experience': 1197,
#  'This': 1187,
#  'way': 1170,
#  'first': 1142,
#  'characters': 1022,
#  '2': 1011,
#  'fun': 1010,
#  'take': 1002,
#  'unique': 965,
#  'get': 951,
#  'must': 929,
#  'great': 905,
#  'series': 882,
#  'good': 853,
#  'well': 840,
#  'combat': 829,
#  'battle': 826,
#  'make': 815,
#  'back': 810,
#  'even': 793,
#  'best': 784,
#  'also': 780,
#  'set': 779,
#  'ever': 767,
#  'really': 759,
#  'life': 754,
#  'based': 740,
#  'find': 722,
#  'features': 719,
#  'None': 700,
#  'control': 699,
#  'As': 664,
#  'different': 659,
#  'enemies': 641,
#  'much': 640,
#  'weapons': 640,
#  'original': 639,
#  'style': 627,
#  'every': 615,
#  'friends': 613,
#  'including': 598,
#  'With': 593,
#  'power': 590,
#  'fight': 589,
#  'across': 583,
#  'playing': 572,
#  'system': 569,
#  'puzzles': 567,
#  'two': 565,
#  'real': 563,
#  'mode': 558,
#  'character': 555,
#  'team': 554,
#  'many': 548,
#  'multiplayer': 546,
#  'around': 535,
#  'classic': 531,
#  'graphics': 524,
#  'role': 521,
#  'mysterious': 519,
#  'love': 512,
#  'use': 511,
#  'city': 507,
#  'online': 504,
#  'level': 503,
#  '10': 502,
#  'takes': 494,
#  'RPG': 493,
#  'played': 489,
#  'journey': 484,
#  'war': 484,
#  'levels': 480,
#  'never': 480,
#  'people': 473,
#  'full': 470,
#  'single': 468,
#  'years': 467,
#  'explore': 466,
#  'high': 461,
#  'puzzle': 457,
#  'But': 455,
#  'powerful': 455,
#  'lot': 453,
#  'If': 450,
#  'strategy': 446,
#  'become': 440,
#  'end': 434,
#  'epic': 433,
#  'little': 432,
#  'long': 432,
#  'battles': 431,
#  '4': 429,
#  'New': 427,
#  'save': 427,
#  'World': 424,
#  'turn': 424,
#  'evil': 420,
#  'would': 419,
#  'abilities': 415,
#  'three': 413,
#  'There': 412,
#  'made': 411,
#  'War': 410,
#  'side': 410,
#  'help': 407,
#  '3': 406,
#  'Players': 405,
#  'old': 402,
#  'person': 401,
#  'dark': 400,
#  'fast': 400,
#  'together': 399,
#  'art': 398,
#  'enemy': 393,
#  'land': 389,
#  'skills': 387,
#  'space': 387,
#  'go': 386,
#  'variety': 385,
#  'music': 377,
#  'better': 373,
#  'day': 372,
#  'missions': 369,
#  'place': 369,
#  'beautiful': 367,
#  'content': 367,
#  'discover': 364,
#  'One': 359,
#  'everything': 359,
#  'top': 355,
#  'shooter': 349,
#  'using': 349,
#  'ancient': 348,
#  'could': 347,
#  'still': 347,
#  '3D': 345,
#  'behind': 343,
#  'modes': 343,
#  'Your': 342,
#  'challenges': 341,
#  'need': 341,
#  'events': 340,
#  'elements': 336,
#  'forces': 336,
#  'co': 335,
#  'bit': 334,
#  'past': 334,
#  'And': 333,
#  'Play': 331,
#  'feel': 331,
#  'create': 330,
#  'challenging': 327,
#  'universe': 327,
#  'home': 326,
#  'challenge': 322,
#  'hours': 322,
#  'last': 321,
#  'next': 321,
#  'deep': 320,
#  'face': 320,
#  'mission': 319,
#  'survive': 319,
#  'things': 318,
#  'young': 316,
#  'complete': 315,
#  'creatures': 315,
#  'see': 314,
#  'part': 313,
#  '1': 312,
#  'right': 312,
#  'genre': 310,
#  'makes': 310,
#  'racing': 309,
#  'controls': 308,
#  'free': 308,
#  'far': 305,
#  'heroes': 304,
#  'arcade': 302,
#  'mechanics': 301,
#  'come': 300,
#  'quest': 298,
#  'want': 298,
#  'Games': 296,
#  'environments': 295,
#  'fighting': 295,
#  'history': 295,
#  'known': 295,
#  'times': 295,
#  'planet': 294,
#  'From': 293,
#  'amazing': 293,
#  'Take': 292,
#  'design': 292,
#  'future': 292,
#  'secrets': 291,
#  'four': 286,
#  'Game': 285,
#  'build': 285,
#  'op': 285,
#  'de': 284,
#  'easy': 282,
#  'hero': 282,
#  'enough': 281,
#  'lead': 281,
#  'give': 278,
#  'keep': 278,
#  'race': 278,
#  'year': 277,
#  'Earth': 276,
#  'enjoy': 276,
#  'hand': 276,
#  'version': 276,
#  'yet': 276,
#  'tactical': 275,
#  'campaign': 273,
#  'When': 272,
#  'comes': 271,
#  'open': 271,
#  'order': 270,
#  'ultimate': 270,
#  'filled': 268,
#  'quite': 266,
#  'II': 265,
#  'hard': 263,
#  'perfect': 263,
#  'say': 263,
#  'special': 263,
#  'think': 261,
#  'within': 261,
#  'offers': 260,
#  'survival': 260,
#  '8': 259,
#  'work': 259,
#  '5': 258,
#  'island': 258,
#  'powers': 258,
#  'After': 257,
#  'choose': 256,
#  'All': 255,
#  'simple': 255,
#  'Explore': 254,
#  'platformer': 254,
#  'something': 254,
#  'true': 254,
#  '2D': 253,
#  'intense': 251,
#  'bring': 250,
#  'modern': 250,
#  'City': 249,
#  'stop': 249,
#  'deadly': 248,
#  'solve': 248,
#  'monsters': 247,
#  'mystery': 247,
#  'An': 245,
#  'alien': 245,
#  'allows': 244,
#  'PC': 243,
#  'along': 243,
#  'learn': 243,
#  'Set': 242,
#  'human': 242,
#  'legendary': 242,
#  'paced': 242,
#  'try': 241,
#  'expansion': 240,
#  'look': 240,
#  'Now': 239,
#  'horror': 239,
#  'may': 239,
#  'thing': 237,
#  'What': 234,
#  'start': 234,
#  'family': 233,
#  'gamers': 233,
#  'massive': 233,
#  'visuals': 232,
#  'another': 231,
#  'brand': 231,
#  'death': 230,
#  'worlds': 229,
#  'Experience': 228,
#  'winning': 228,
#  'got': 227,
#  'environment': 226,
#  'created': 225,
#  'fans': 225,
#  'know': 225,
#  'Great': 224,
#  'small': 224,
#  'For': 223,
#  'gaming': 223,
#  'town': 223,
#  'change': 222,
#  'since': 222,
#  'without': 222,
#  'left': 221,
#  'entire': 220,
#  'master': 220,
#  'though': 220,
#  'throughout': 219,
#  'fantasy': 217,
#  'short': 217,
#  'heart': 216,
#  'locations': 216,
#  'realistic': 216,
#  'sound': 216,
#  'soundtrack': 216,
#  'title': 216,
#  'mind': 215,
#  'vast': 215,
#  'interesting': 214,
#  'put': 214,
#  'point': 213,
#  'whole': 213,
#  'choices': 212,
#  'Battle': 211,
#  'making': 210,
#  'living': 209,
#  'search': 209,
#  'magic': 208,
#  'vehicles': 208,
#  'friend': 207,
#  'huge': 207,
#  'inspired': 207,
#  'Nintendo': 206,
#  'ability': 206,
#  'brings': 206,
#  'secret': 206,
#  'uncover': 206,
#  'Each': 203,
#  'able': 203,
#  'exploration': 203,
#  'lost': 203,
#  'recommend': 203,
#  'worth': 203,
#  'dangerous': 202,
#  'defeat': 202,
#  'fan': 202,
#  'man': 202,
#  'sequel': 202,
#  'building': 201,
#  'seen': 201,
#  'head': 200,
#  'packed': 200,
#  'strange': 199,
#  'force': 198,
#  'hidden': 198,
#  'award': 197,
#  'awesome': 197,
#  'pretty': 197,
#  'stunning': 197,
#  'units': 197,
#  'exciting': 196,
#  'run': 196,
#  'Mode': 194,
#  'favorite': 194,
#  'alone': 193,
#  'final': 192,
#  'VR': 191,
#  'Xbox': 191,
#  'main': 191,
#  'big': 190,
#  'Dark': 189,
#  'Star': 189,
#  'Switch': 189,
#  'designed': 189,
#  'military': 189,
#  'fantastic': 188,
#  'join': 188,
#  'looking': 188,
#  'path': 188,
#  'They': 187,
#  'done': 187,
#  'attack': 186,
#  'fully': 186,
#  'nice': 186,
#  'At': 185,
#  'hope': 185,
#  'incredible': 185,
#  'physics': 185,
#  'return': 185,
#  'everyone': 184,
#  'ship': 184,
#  'gets': 183,
#  'means': 183,
#  'featuring': 182,
#  'highly': 182,
#  'always': 181,
#  'includes': 181,
#  'items': 181,
#  'playable': 181,
#  'strategic': 181,
#  'truth': 181,
#  'To': 180,
#  'bad': 180,
#  'local': 180,
#  'technology': 180,
#  'available': 179,
#  'escape': 179,
#  'franchise': 179,
#  'video': 179,
#  'air': 178,
#  'upon': 178,
#  'ways': 178,
#  'addition': 177,
#  'completely': 177,
#  'races': 177,
#  'tale': 177,
#  'fate': 176,
#  'might': 176,
#  'party': 176,
#  'Super': 175,
#  'engine': 175,
#  'moves': 175,
#  'ready': 175,
#  'school': 175,
#  'beat': 174,
#  'que': 174,
#  'Empire': 173,
#  'away': 173,
#  'buy': 173,
#  'found': 173,
#  'going': 173,
#  'humanity': 173,
#  'job': 173,
#  'difficulty': 172,
#  'enjoyed': 172,
#  'Interactive': 171,
#  'Wars': 171,
#  'cars': 171,
#  'light': 170,
#  'skill': 170,
#  'tracks': 170,
#  'weapon': 170,
#  'hit': 169,
#  'multiple': 169,
#  'various': 169,
#  'five': 168,
#  'definitely': 166,
#  'detailed': 166,
#  'called': 165,
#  'options': 165,
#  'test': 165,
#  'types': 165,
#  'beyond': 164,
#  'group': 164,
#  'immersive': 164,
#  'anything': 163,
#  'pack': 163,
#  'used': 163,
#  'amount': 162,
#  'army': 162,
#  'atmosphere': 162,
#  'dead': 162,
#  'depth': 162,
#  'dynamic': 162,
#  'form': 162,
#  'King': 161,
#  'Sims': 161,
#  'magical': 161,
#  'speed': 161,
#  '20': 160,
#  'super': 160,
#  'While': 159,
#  'attacks': 159,
#  'greatest': 159,
#  'inside': 159,
#  'live': 159,
#  'lives': 159,
#  'opponents': 159,
#  'price': 159,
#  'quests': 159,
#  'AI': 158,
#  'truly': 157,
#  'Evil': 156,
#  'destruction': 156,
#  'feels': 156,
#  'iconic': 156,
#  'simulation': 156,
#  'No': 155,
#  'adventures': 155,
#  'cities': 155,
#  'third': 155,
#  'unlock': 155,
#  'Europe': 154,
#  'storyline': 154,
#  'course': 153,
#  'latest': 153,
#  'narrative': 153,
#  'nothing': 153,
#  'released': 153,
#  'и': 153,
#  'addictive': 152,
#  'driven': 152,
#  'getting': 152,
#  'effects': 150,
#  'key': 150,
#  'Edition': 149,
#  'chance': 149,
#  'destroy': 149,
#  'finds': 149,
#  'maps': 149,
#  'cast': 148,
#  'line': 148,
#  'resources': 148,
#  'travel': 148,
#  'Can': 147,
#  'decisions': 147,
#  'finally': 147,
#  'puts': 147,
#  'tactics': 147,
#  'em': 146,
#  'reality': 146,
#  'track': 146,
#  'chaos': 145,
#  'com': 145,
#  'difficult': 145,
#  'girl': 145,
#  'acclaimed': 144,
#  'episode': 144,
#  'screen': 144,
#  'six': 144,
#  'sure': 144,
#  'Man': 143,
#  'moments': 143,
#  'possible': 143,
#  'Arts': 142,
#  'Use': 142,
#  'actions': 142,
#  'allowing': 142,
#  'enjoyable': 142,
#  'move': 142,
#  'returns': 142,
#  'He': 141,
#  'galaxy': 141,
#  'show': 141,
#  'brutal': 140,
#  'pick': 140,
#  'Online': 139,
#  'Will': 139,
#  'collection': 139,
#  'command': 139,
#  'gives': 139,
#  'setting': 139,
#  'DLC': 138,
#  'choice': 138,
#  'elite': 138,
#  'freedom': 138,
#  'hands': 138,
#  '30': 137,
#  'Time': 137,
#  'let': 137,
#  'advanced': 136,
#  'combines': 136,
#  'night': 136,
#  'retro': 136,
#  'second': 136,
#  'several': 136,
#  'support': 136,
#  'taking': 136,
#  'Electronic': 135,
#  'era': 135,
#  'foes': 135,
#  'number': 135,
#  'range': 135,
#  'release': 135,
#  'Age': 134,
#  'armies': 134,
#  'begins': 134,
#  'brought': 134,
#  'either': 134,
#  'lands': 134,
#  'meet': 134,
#  'squad': 134,
#  'visual': 134,
#  'indie': 133,
#  'others': 133,
#  'step': 133,
#  'However': 132,
#  'boss': 132,
#  'map': 132,
#  'sets': 132,
#  'trying': 132,
#  'S': 131,
#  'add': 131,
#  'developed': 131,
#  'improved': 131,
#  'soon': 131,
#  'thought': 131,
#  'Also': 130,
#  'areas': 130,
#  'encounter': 130,
#  'stories': 130,
#  'voice': 130,
#  'enhanced': 129,
#  'named': 129,
#  'score': 129,
#  'First': 128,
#  'coming': 128,
#  'crew': 128,
#  'exploring': 128,
#  'offer': 128,
#  '100': 127,
#  'Adventure': 127,
#  'almost': 127,
#  'anyone': 127,
#  'feature': 127,
#  'ground': 127,
#  'jump': 127,
#  'loved': 127,
#  'overcome': 127,
#  'plot': 127,
#  'quickly': 127,
#  'streets': 127,
#  'arsenal': 126,
#  'balance': 126,
#  'career': 126,
#  'important': 126,
#  'money': 126,
#  'obstacles': 126,
#  'threat': 126,
#  'LEGO': 125,
#  'battlefield': 125,
#  'rich': 125,
#  'victory': 125,
#  'в': 125,
#  'bosses': 124,
#  'close': 124,
#  'hundreds': 124,
#  'kingdom': 124,
#  'match': 124,
#  'mysteries': 124,
#  'seems': 124,
#  'Master': 123,
#  'conflict': 123,
#  'looks': 123,
#  'Choose': 122,
#  'On': 122,
#  'fresh': 122,
#  'goal': 122,
#  'interactive': 122,
#  'post': 122,
#  'sense': 122,
#  'Join': 121,
#  'kind': 121,
#  'progress': 121,
#  'spells': 121,
#  'teams': 121,
#  'crime': 120,
#  'hordes': 120,
#  'mix': 120,
#  'village': 120,
#  'Build': 119,
#  'Space': 119,
#  'Japan': 118,
#  'Just': 118,
#  'ago': 118,
#  'complex': 118,
#  'fire': 118,
#  'shoot': 118,
#  'struggle': 118,
#  'So': 117,
#  'generation': 117,
#  'platform': 117,
#  'present': 117,
#  'previous': 117,
#  'Dead': 116,
#  'That': 116,
#  'alive': 116,
#  'car': 116,
#  'edge': 116,
#  'famous': 116,
#  'U': 115,
#  'additional': 115,
#  'community': 115,
#  'earn': 115,
#  'generated': 115,
#  'presentation': 115,
#  'unknown': 115,
#  'adds': 114,
#  'compete': 114,
#  'entirely': 114,
#  'factions': 114,
#  'name': 114,
#  'platforming': 114,
#  'road': 114,
#  'changing': 113,
#  'cool': 113,
#  'delivers': 113,
#  'empire': 113,
#  'endless': 113,
#  'stand': 113,
#  'added': 112,
#  'century': 112,
#  'collect': 112,
#  'darkness': 112,
#  'developers': 112,
#  'us': 112,
#  'wide': 112,
#  'Every': 111,
#  'Fight': 111,
#  'Get': 111,
#  'already': 111,
#  'conquer': 111,
#  'core': 111,
#  'earth': 111,
#  'follows': 111,
#  'however': 111,
#  'introduces': 111,
#  'un': 111,
#  'die': 110,
#  'robot': 110,
#  'titles': 110,
#  'win': 110,
#  '6': 109,
#  'Black': 109,
#  'competitive': 109,
#  'continues': 109,
#  'dungeon': 109,
#  'follow': 109,
#  'season': 109,
#  'American': 108,
#  'RTS': 108,
#  'chapter': 108,
#  'creators': 108,
#  'days': 108,
#  'decide': 108,
#  'development': 108,
#  'driving': 108,
#  'giant': 108,
#  'provides': 108,
#  'Only': 107,
#  'absolutely': 107,
#  'campaigns': 107,
#  'humans': 107,
#  'management': 107,
#  'parts': 107,
#  'wrong': 107,
#  'actually': 106,
#  'age': 106,
#  'kill': 106,
#  'soldiers': 106,
#  'systems': 106,
#  '9': 105,
#  'Japanese': 105,
#  'becomes': 105,
#  'e': 105,
#  'innovative': 105,
#  'stages': 105,
#  'thrilling': 105,
#  '50': 104,
#  'Not': 104,
#  'Ubisoft': 104,
#  'Welcome': 104,
#  'especially': 104,
#  'large': 104,
#  'terrifying': 104,
#  'Force': 103,
#  'Heroes': 103,
#  'North': 103,
#  'allow': 103,
#  'array': 103,
#  'blast': 103,
#  'break': 103,
#  'detail': 103,
#  'Knight': 102,
#  'embark': 102,
#  'forward': 102,
#  'issues': 102,
#  'lets': 102,
#  'objects': 102,
#  'popular': 102,
#  'protect': 102,
#  'reach': 102,
#  'waiting': 102,
#  '7': 101,
#  'click': 101,
#  'peace': 101,
#  'stealth': 101,
#  'Dragon': 100,
#  'R': 100,
#  'We': 100,
#  'crazy': 100,
#  'guns': 100,
#  'sea': 100,
#  'Create': 99,
#  'D': 99,
#  'guide': 99,
#  'non': 99,
#  'quality': 99,
#  'scale': 99,
#  'scrolling': 99,
#  'HD': 98,
#  'call': 98,
#  'diverse': 98,
#  'drawn': 98,
#  'dungeons': 98,
#  'missing': 98,
#  'stage': 98,
#  '16': 97,
#  'Even': 97,
#  'III': 97,
#  'Resident': 97,
#  'assume': 97,
#  'fact': 97,
#  'film': 97,
#  'gain': 97,
#  'leader': 97,
#  'plays': 97,
#  'taken': 97,
#  'Its': 96,
#  'enter': 96,
#  'fall': 96,
#  'given': 96,
#  'hostile': 96,
#  'major': 96,
#  'overall': 96,
#  'remember': 96,
#  'switch': 96,
#  '12': 95,
#  '40': 95,
#  'Entertainment': 95,
#  'Featuring': 95,
#  'Life': 95,
#  'built': 95,
#  'class': 95,
#  'demon': 95,
#  'equipment': 95,
#  'fights': 95,
#  'rescue': 95,
#  'solid': 95,
#  'solving': 95,
#  'weaponry': 95,
#  'Become': 94,
#  'authentic': 94,
#  'console': 94,
#  'distant': 94,
#  'eight': 94,
#  'ending': 94,
#  'legend': 94,
#  'machine': 94,
#  'mechanic': 94,
#  'murder': 94,
#  'problems': 94,
#  'provide': 94,
#  'stay': 94,
#  'traps': 94,
#  'America': 93,
#  'Don': 93,
#  'Hell': 93,
#  'Story': 93,
#  'apocalyptic': 93,
#  'beginning': 93,
#  'blood': 93,
#  'defend': 93,
#  'desperate': 93,
#  'expect': 93,
#  'giving': 93,
#  'hell': 93,
#  'include': 93,
#  'near': 93,
#  'plus': 93,
#  'ruins': 93,
#  'Two': 92,
#  'customize': 92,
#  'destiny': 92,
#  'drive': 92,
#  'felt': 92,
#  'global': 92,
#  'robots': 92,
#  'terms': 92,
#  'upgrades': 92,
#  '000': 91,
#  'Island': 91,
#  'ball': 91,
#  'base': 91,
#  'deliver': 91,
#  'demons': 91,
#  'stick': 91,
#  'trapped': 91,
#  'upgrade': 91,
#  'computer': 90,
#  'critically': 90,
#  'customization': 90,
#  'goes': 90,
#  'gone': 90,
#  'matter': 90,
#  'needs': 90,
#  'ships': 90,
#  'Enter': 89,
#  'German': 89,
#  'Monster': 89,
#  'X': 89,
#  'colorful': 89,
#  'cult': 89,
#  'extremely': 89,
#  'familiar': 89,
#  'feeling': 89,
#  'leave': 89,
#  'personal': 89,
#  'plan': 89,
#  'problem': 89,
#  'strong': 89,
#  'unravel': 89,
#  'ups': 89,
#  'Strategy': 88,
#  'Studios': 88,
#  'abandoned': 88,
#  'begin': 88,
#  'biggest': 88,
#  'buildings': 88,
#  'charming': 88,
#  'civilization': 88,
#  'gun': 88,
#  'historical': 88,
#  'hold': 88,
#  'la': 88,
#  'later': 88,
#  'multi': 88,
#  'remastered': 88,
#  'restore': 88,
#  'scenarios': 88,
#  'star': 88,
#  'total': 88,
#  'warriors': 88,
#  'Kingdom': 87,
#  'My': 87,
#  'THE': 87,
#  'animals': 87,
#  'castle': 87,
#  'clear': 87,
#  'color': 87,
#  'father': 87,
#  'hunt': 87,
#  'official': 87,
#  'turns': 87,
#  'vs': 87,
#  'Team': 86,
#  'changes': 86,
#  'classes': 86,
#  'danger': 86,
#  'dream': 86,
#  'funny': 86,
#  'leading': 86,
#  'low': 86,
#  'machines': 86,
#  'memories': 86,
#  'nature': 86,
#  'reason': 86,
#  'rogue': 86,
#  'tells': 86,
#  'terrain': 86,
#  'warrior': 86,
#  'These': 85,
#  'allies': 85,
#  'book': 85,
#  'certain': 85,
#  'creative': 85,
#  'rise': 85,
#  'running': 85,
#  'shooting': 85,
#  'started': 85,
#  'terrible': 85,
#  'tools': 85,
#  'Episode': 84,
#  'More': 84,
#  'Of': 84,
#  'combine': 84,
#  'decent': 84,
#  'depths': 84,
#  'doubt': 84,
#  'easily': 84,
#  'expand': 84,
#  'futuristic': 84,
#  'incredibly': 84,
#  'research': 84,
#  'underground': 84,
#  'wonderful': 84,
#  '15': 83,
#  ...}

# %% [markdown]
# 부정적인 단어 빈도수

# %%
dic_neg
# Out:
# {'game': 3043,
#  'The': 1989,
#  'new': 1567,
#  'I': 1504,
#  'world': 1054,
#  'players': 857,
#  'play': 684,
#  'time': 675,
#  'like': 634,
#  'one': 620,
#  'story': 585,
#  'player': 542,
#  'It': 541,
#  'experience': 521,
#  'A': 485,
#  'In': 470,
#  'action': 463,
#  'first': 462,
#  'games': 453,
#  'This': 431,
#  'way': 428,
#  'You': 422,
#  'gameplay': 417,
#  'take': 411,
#  'adventure': 393,
#  'fun': 377,
#  'get': 360,
#  'life': 356,
#  'unique': 332,
#  'back': 331,
#  '2': 322,
#  'combat': 318,
#  'also': 316,
#  'even': 313,
#  'good': 311,
#  'great': 311,
#  'control': 309,
#  'must': 305,
#  'characters': 302,
#  'features': 297,
#  'battle': 295,
#  'real': 285,
#  'weapons': 281,
#  'series': 271,
#  'set': 269,
#  'fight': 265,
#  'make': 265,
#  'well': 265,
#  'best': 264,
#  'online': 263,
#  'really': 263,
#  'every': 262,
#  'ever': 261,
#  'including': 260,
#  'based': 258,
#  'friends': 252,
#  'team': 249,
#  'different': 246,
#  'As': 244,
#  'mode': 237,
#  'across': 236,
#  'multiplayer': 236,
#  'find': 234,
#  'around': 231,
#  'system': 227,
#  'city': 221,
#  'takes': 219,
#  'character': 216,
#  'people': 216,
#  'power': 214,
#  'With': 213,
#  'person': 209,
#  'use': 208,
#  'enemies': 207,
#  'two': 205,
#  'much': 204,
#  'style': 203,
#  'graphics': 200,
#  'journey': 199,
#  'high': 196,
#  'many': 194,
#  'racing': 191,
#  '4': 190,
#  'powerful': 190,
#  'years': 190,
#  '10': 188,
#  'long': 186,
#  'would': 186,
#  'New': 184,
#  'full': 184,
#  'level': 182,
#  'original': 182,
#  'World': 181,
#  'never': 180,
#  'war': 179,
#  'But': 178,
#  'become': 178,
#  'Players': 177,
#  'levels': 177,
#  '3': 176,
#  'epic': 174,
#  'If': 172,
#  'love': 171,
#  'classic': 167,
#  'single': 166,
#  'go': 165,
#  'playing': 164,
#  'explore': 162,
#  'role': 162,
#  'skills': 162,
#  'Play': 160,
#  'better': 160,
#  'shooter': 160,
#  'need': 159,
#  'modes': 158,
#  'abilities': 157,
#  'end': 157,
#  'mysterious': 157,
#  'place': 157,
#  'feel': 156,
#  'save': 156,
#  'together': 155,
#  'create': 154,
#  'right': 154,
#  'There': 152,
#  'next': 149,
#  'played': 149,
#  'race': 148,
#  'challenges': 147,
#  'fast': 147,
#  'War': 146,
#  'old': 146,
#  'little': 145,
#  'face': 144,
#  'side': 144,
#  'year': 144,
#  'four': 143,
#  'see': 143,
#  'events': 142,
#  'three': 142,
#  'universe': 142,
#  'bit': 141,
#  'challenge': 140,
#  'variety': 140,
#  'missions': 137,
#  'space': 137,
#  'One': 135,
#  'puzzles': 135,
#  'strategy': 135,
#  'lot': 134,
#  'mission': 133,
#  'open': 133,
#  'battles': 132,
#  'enemy': 132,
#  'last': 132,
#  'content': 131,
#  'controls': 130,
#  'Take': 129,
#  'planet': 129,
#  'using': 128,
#  'still': 127,
#  'environments': 126,
#  'free': 125,
#  'build': 124,
#  'co': 124,
#  'part': 123,
#  'RPG': 122,
#  'When': 122,
#  'future': 122,
#  'genre': 121,
#  'help': 121,
#  'home': 121,
#  'made': 121,
#  'something': 121,
#  'come': 120,
#  'dark': 120,
#  'forces': 120,
#  'past': 120,
#  '1': 119,
#  'And': 119,
#  'day': 119,
#  'evil': 119,
#  'Experience': 118,
#  'give': 118,
#  'land': 118,
#  'far': 117,
#  'II': 116,
#  'behind': 116,
#  'could': 114,
#  'deep': 114,
#  'top': 114,
#  'turn': 113,
#  'Earth': 112,
#  'Now': 112,
#  'Star': 112,
#  'fans': 112,
#  'offers': 112,
#  'Games': 111,
#  'Your': 111,
#  'modern': 111,
#  'From': 110,
#  'enjoy': 110,
#  'times': 110,
#  'None': 109,
#  'ancient': 109,
#  'beautiful': 109,
#  'comes': 109,
#  '3D': 108,
#  'gamers': 108,
#  'puzzle': 108,
#  'things': 108,
#  'arcade': 107,
#  'complete': 107,
#  'known': 107,
#  'All': 106,
#  'art': 106,
#  'enough': 106,
#  'heroes': 106,
#  'music': 106,
#  'want': 106,
#  'fan': 105,
#  'history': 105,
#  'look': 105,
#  'hours': 104,
#  'de': 103,
#  'fighting': 103,
#  'intense': 103,
#  'op': 103,
#  'bad': 102,
#  'brings': 102,
#  'campaign': 102,
#  'massive': 102,
#  'yet': 102,
#  'know': 101,
#  'live': 101,
#  'may': 101,
#  'order': 101,
#  'quite': 101,
#  'work': 101,
#  'For': 100,
#  'franchise': 100,
#  'human': 100,
#  'perfect': 100,
#  'ultimate': 100,
#  'young': 100,
#  'An': 99,
#  'tactical': 99,
#  'bring': 98,
#  'challenging': 98,
#  'allows': 97,
#  'discover': 97,
#  'filled': 97,
#  'survive': 97,
#  'think': 97,
#  'family': 96,
#  'favorite': 96,
#  'keep': 96,
#  'Explore': 95,
#  'design': 95,
#  'put': 95,
#  '20': 94,
#  'Game': 94,
#  'special': 94,
#  '5': 93,
#  'able': 93,
#  'exciting': 93,
#  'makes': 93,
#  'mechanics': 93,
#  'throughout': 93,
#  'everything': 92,
#  'learn': 92,
#  'realistic': 92,
#  'Battle': 91,
#  'easy': 91,
#  'lost': 91,
#  'secrets': 91,
#  'City': 90,
#  'alien': 90,
#  'hard': 90,
#  'locations': 90,
#  'technology': 90,
#  'town': 90,
#  'within': 90,
#  'amazing': 89,
#  'elements': 89,
#  'packed': 89,
#  'solve': 89,
#  'whole': 89,
#  'cars': 88,
#  'choose': 88,
#  'creatures': 88,
#  'deadly': 88,
#  'found': 88,
#  'horror': 88,
#  'speed': 88,
#  'dynamic': 87,
#  'point': 87,
#  'man': 86,
#  'true': 86,
#  'worlds': 86,
#  'defeat': 85,
#  'head': 85,
#  'powers': 85,
#  'say': 85,
#  'video': 85,
#  'NBA': 84,
#  'career': 84,
#  'match': 84,
#  'secret': 84,
#  'start': 84,
#  'survival': 84,
#  'environment': 83,
#  'featuring': 83,
#  'lead': 83,
#  'though': 83,
#  'To': 82,
#  'Wars': 82,
#  'since': 82,
#  'used': 82,
#  'vehicles': 82,
#  'ways': 82,
#  '8': 81,
#  'WWE': 81,
#  'along': 81,
#  'heart': 81,
#  'humanity': 81,
#  'looking': 81,
#  'quest': 81,
#  'Xbox': 80,
#  'change': 80,
#  'physics': 80,
#  'short': 80,
#  'thing': 80,
#  'without': 80,
#  'They': 79,
#  'ability': 79,
#  'brand': 79,
#  'force': 79,
#  'iconic': 79,
#  'main': 79,
#  'run': 79,
#  'small': 79,
#  'version': 79,
#  'competitive': 78,
#  'entire': 78,
#  'hero': 78,
#  'legendary': 78,
#  'making': 78,
#  'simple': 78,
#  'tracks': 78,
#  'Set': 77,
#  'gives': 77,
#  'huge': 77,
#  'inspired': 77,
#  'line': 77,
#  'paced': 77,
#  'races': 77,
#  'stop': 77,
#  'another': 76,
#  'beat': 76,
#  'elite': 76,
#  'maps': 76,
#  'third': 76,
#  'vast': 76,
#  'compete': 75,
#  'seen': 75,
#  'PC': 74,
#  'away': 74,
#  'course': 74,
#  'dangerous': 74,
#  'death': 74,
#  'fantasy': 74,
#  'master': 74,
#  'After': 73,
#  'Arts': 73,
#  'anything': 73,
#  'going': 73,
#  'military': 73,
#  'show': 73,
#  'simulation': 73,
#  'FIFA': 72,
#  'friend': 72,
#  'unlock': 72,
#  'Each': 71,
#  'Interactive': 71,
#  'beyond': 71,
#  'created': 71,
#  'got': 71,
#  'puts': 71,
#  'title': 71,
#  'Mode': 70,
#  'available': 70,
#  'chance': 70,
#  'gaming': 70,
#  'hand': 70,
#  'hit': 70,
#  'lets': 70,
#  'monsters': 70,
#  'moves': 70,
#  'mystery': 70,
#  'test': 70,
#  'Electronic': 69,
#  'What': 69,
#  'authentic': 69,
#  'choices': 69,
#  'customize': 69,
#  'interesting': 69,
#  'mind': 69,
#  'que': 69,
#  'ship': 69,
#  'Call': 68,
#  'alone': 68,
#  'always': 68,
#  'final': 68,
#  'island': 68,
#  'join': 68,
#  'left': 68,
#  'map': 68,
#  'opponents': 68,
#  'teams': 68,
#  'DLC': 67,
#  'VR': 67,
#  'items': 67,
#  'magic': 67,
#  'multiple': 67,
#  'options': 67,
#  'skill': 67,
#  'various': 67,
#  'ready': 66,
#  'try': 66,
#  'Use': 65,
#  'big': 65,
#  'either': 65,
#  'escape': 65,
#  'nice': 65,
#  'return': 65,
#  'super': 65,
#  'uncover': 65,
#  'Sims': 64,
#  'Welcome': 64,
#  'addition': 64,
#  'driven': 64,
#  'exploration': 64,
#  'famous': 64,
#  'global': 64,
#  'highly': 64,
#  'hope': 64,
#  'nothing': 64,
#  'path': 64,
#  'Create': 63,
#  'On': 63,
#  'feels': 63,
#  'hidden': 63,
#  'immersive': 63,
#  'pretty': 63,
#  'seems': 63,
#  'While': 62,
#  'building': 62,
#  'designed': 62,
#  'done': 62,
#  'freedom': 62,
#  'fully': 62,
#  'introduces': 62,
#  'Black': 61,
#  'air': 61,
#  'close': 61,
#  'enjoyed': 61,
#  'group': 61,
#  'incredible': 61,
#  'kind': 61,
#  'light': 61,
#  'range': 61,
#  'sure': 61,
#  'trying': 61,
#  'visuals': 61,
#  'No': 60,
#  'Switch': 60,
#  'army': 60,
#  'attack': 60,
#  'cities': 60,
#  'com': 60,
#  'crew': 60,
#  'deliver': 60,
#  'enjoyable': 60,
#  'generation': 60,
#  'ground': 60,
#  'streets': 60,
#  'Dead': 59,
#  'Nintendo': 59,
#  'depth': 59,
#  'driving': 59,
#  'latest': 59,
#  'official': 59,
#  'playable': 59,
#  'Dark': 58,
#  'EA': 58,
#  'Great': 58,
#  'edge': 58,
#  'engine': 58,
#  'fantastic': 58,
#  'form': 58,
#  'includes': 58,
#  'screen': 58,
#  'stories': 58,
#  'un': 58,
#  'winning': 58,
#  'AI': 57,
#  'American': 57,
#  'Duty': 57,
#  'Just': 57,
#  'Super': 57,
#  'car': 57,
#  'jump': 57,
#  'party': 57,
#  'price': 57,
#  'road': 57,
#  'taking': 57,
#  'types': 57,
#  'Choose': 56,
#  'areas': 56,
#  'community': 56,
#  'conflict': 56,
#  'night': 56,
#  'release': 56,
#  'resources': 56,
#  'search': 56,
#  'stunning': 56,
#  'tactics': 56,
#  'track': 56,
#  'voice': 56,
#  'Empire': 55,
#  'NFL': 55,
#  'advanced': 55,
#  'detailed': 55,
#  'personal': 55,
#  'pick': 55,
#  'rise': 55,
#  'sound': 55,
#  'step': 55,
#  'truly': 55,
#  'upgrade': 55,
#  'vehicle': 55,
#  'worth': 55,
#  'actually': 54,
#  'allow': 54,
#  'ball': 54,
#  'called': 54,
#  'crime': 54,
#  'gain': 54,
#  'getting': 54,
#  'giving': 54,
#  'means': 54,
#  'move': 54,
#  'platform': 54,
#  'reality': 54,
#  'threat': 54,
#  'thrilling': 54,
#  'Featuring': 53,
#  'allowing': 53,
#  'amount': 53,
#  'awesome': 53,
#  'blood': 53,
#  'delivers': 53,
#  'difficulty': 53,
#  'earn': 53,
#  'five': 53,
#  'let': 53,
#  'movie': 53,
#  'progress': 53,
#  'score': 53,
#  'upon': 53,
#  'weapon': 53,
#  'win': 53,
#  '6': 52,
#  'Every': 52,
#  'So': 52,
#  'Team': 52,
#  'atmosphere': 52,
#  'cast': 52,
#  'dead': 52,
#  'era': 52,
#  'everyone': 52,
#  'might': 52,
#  'season': 52,
#  'squad': 52,
#  'Its': 51,
#  'alive': 51,
#  'allies': 51,
#  'developers': 51,
#  'fate': 51,
#  'foes': 51,
#  'local': 51,
#  'moments': 51,
#  'money': 51,
#  'At': 50,
#  'However': 50,
#  'S': 50,
#  'Warfare': 50,
#  'York': 50,
#  'advantage': 50,
#  'arsenal': 50,
#  'factions': 50,
#  'gear': 50,
#  'gets': 50,
#  'improved': 50,
#  'key': 50,
#  'lives': 50,
#  'looks': 50,
#  'magical': 50,
#  'manage': 50,
#  'offer': 50,
#  'possible': 50,
#  'post': 50,
#  'storyline': 50,
#  'support': 50,
#  'systems': 50,
#  'Fight': 49,
#  'First': 49,
#  'Force': 49,
#  'King': 49,
#  'Ubisoft': 49,
#  'brutal': 49,
#  'destroy': 49,
#  'fresh': 49,
#  'greatest': 49,
#  'living': 49,
#  'mix': 49,
#  'multi': 49,
#  'name': 49,
#  'overcome': 49,
#  'popular': 49,
#  'quests': 49,
#  'recommend': 49,
#  'rich': 49,
#  'running': 49,
#  'survivors': 49,
#  'Be': 48,
#  'Join': 48,
#  'Master': 48,
#  'body': 48,
#  'buy': 48,
#  'call': 48,
#  'coming': 48,
#  'especially': 48,
#  'platformer': 48,
#  'ride': 48,
#  'state': 48,
#  'Build': 47,
#  'NHL': 47,
#  'destruction': 47,
#  'expansion': 47,
#  'film': 47,
#  'inside': 47,
#  'la': 47,
#  'solo': 47,
#  'soundtrack': 47,
#  'stay': 47,
#  'traps': 47,
#  'almost': 46,
#  'boss': 46,
#  'date': 46,
#  'encounter': 46,
#  'episode': 46,
#  'former': 46,
#  'job': 46,
#  'lines': 46,
#  'movement': 46,
#  'reviews': 46,
#  'stand': 46,
#  'tale': 46,
#  'upgrades': 46,
#  'wide': 46,
#  'Online': 45,
#  'That': 45,
#  'attacks': 45,
#  'biggest': 45,
#  'cool': 45,
#  'diverse': 45,
#  'dream': 45,
#  'enhanced': 45,
#  'glory': 45,
#  'issues': 45,
#  'others': 45,
#  'returns': 45,
#  'rewards': 45,
#  'sequel': 45,
#  'stealth': 45,
#  '30': 44,
#  'D': 44,
#  'League': 44,
#  'WRC': 44,
#  'begins': 44,
#  'chaos': 44,
#  'class': 44,
#  'customization': 44,
#  'galaxy': 44,
#  'given': 44,
#  'house': 44,
#  'interactive': 44,
#  'least': 44,
#  'major': 44,
#  'missing': 44,
#  'nation': 44,
#  'near': 44,
#  'previous': 44,
#  'problems': 44,
#  'progression': 44,
#  'quick': 44,
#  'quickly': 44,
#  'review': 44,
#  'shooting': 44,
#  'thought': 44,
#  'virtual': 44,
#  'Combat': 43,
#  'Get': 43,
#  'PlayStation': 43,
#  'add': 43,
#  'alongside': 43,
#  'animations': 43,
#  'brought': 43,
#  'capture': 43,
#  'innovative': 43,
#  'parts': 43,
#  'pitch': 43,
#  'points': 43,
#  'released': 43,
#  'struggle': 43,
#  'tools': 43,
#  'understand': 43,
#  'weaponry': 43,
#  'Studios': 42,
#  'These': 42,
#  'We': 42,
#  'ago': 42,
#  'array': 42,
#  'becomes': 42,
#  'decisions': 42,
#  'distinct': 42,
#  'feature': 42,
#  'fly': 42,
#  'globe': 42,
#  'goal': 42,
#  'low': 42,
#  'named': 42,
#  'park': 42,
#  'protect': 42,
#  'school': 42,
#  'strange': 42,
#  'units': 42,
#  'zombies': 42,
#  '15': 41,
#  '9': 41,
#  'Adventure': 41,
#  'Edition': 41,
#  'Enjoy': 41,
#  'Live': 41,
#  'Ops': 41,
#  'Player': 41,
#  'added': 41,
#  'competition': 41,
#  'completely': 41,
#  'console': 41,
#  'cooperative': 41,
#  'craft': 41,
#  'creative': 41,
#  'customizable': 41,
#  'days': 41,
#  'definitely': 41,
#  'difficult': 41,
#  'fire': 41,
#  'goes': 41,
#  'hunt': 41,
#  'less': 41,
#  'machine': 41,
#  'moment': 41,
#  'pack': 41,
#  'performance': 41,
#  'several': 41,
#  'street': 41,
#  'truth': 41,
#  'victory': 41,
#  'vs': 41,
#  'wrong': 41,
#  '40': 40,
#  'III': 40,
#  'Man': 40,
#  'Red': 40,
#  'THE': 40,
#  'TV': 40,
#  'award': 40,
#  'bosses': 40,
#  'cinematic': 40,
#  'combination': 40,
#  'creativity': 40,
#  'drive': 40,
#  'early': 40,
#  'hell': 40,
#  'rogue': 40,
#  'star': 40,
#  'stars': 40,
#  'studio': 40,
#  '7': 39,
#  'Assassin': 39,
#  'Destiny': 39,
#  'Lord': 39,
#  'command': 39,
#  'conquer': 39,
#  'decide': 39,
#  'developed': 39,
#  'effects': 39,
#  'equipment': 39,
#  'familiar': 39,
#  'finds': 39,
#  'guns': 39,
#  'hands': 39,
#  'hundreds': 39,
#  'needs': 39,
#  'number': 39,
#  'robot': 39,
#  'sea': 39,
#  'soon': 39,
#  'strategic': 39,
#  '2D': 38,
#  'Also': 38,
#  'Diablo': 38,
#  'Dragon': 38,
#  'Jump': 38,
#  'My': 38,
#  'Not': 38,
#  'Only': 38,
#  'beginning': 38,
#  'blast': 38,
#  'century': 38,
#  'danger': 38,
#  'felt': 38,
#  'generated': 38,
#  'giant': 38,
#  'guide': 38,
#  'management': 38,
#  'narrative': 38,
#  'second': 38,
#  'travel': 38,
#  '100': 37,
#  '21': 37,
#  'Age': 37,
#  'Road': 37,
#  'Special': 37,
#  'Sports': 37,
#  'attempt': 37,
#  'darkness': 37,
#  'defend': 37,
#  'development': 37,
#  'empire': 37,
#  'ending': 37,
#  'finally': 37,
#  'kill': 37,
#  'memories': 37,
#  'non': 37,
#  'runs': 37,
#  'sense': 37,
#  'underground': 37,
#  'Don': 36,
#  'Pro': 36,
#  'acclaimed': 36,
#  'age': 36,
#  'apocalyptic': 36,
#  'area': 36,
#  'balance': 36,
#  'base': 36,
#  'begin': 36,
#  'collect': 36,
#  'collection': 36,
#  'continues': 36,
#  'exploring': 36,
#  'forward': 36,
#  'ice': 36,
#  'lands': 36,
#  'loved': 36,
#  'obstacles': 36,
#  'provide': 36,
#  'roster': 36,
#  'scale': 36,
#  'shot': 36,
#  'us': 36,
#  '18': 35,
#  'FPS': 35,
#  'HD': 35,
#  'Multiplayer': 35,
#  'Order': 35,
#  'Whether': 35,
#  'Will': 35,
#  'addictive': 35,
#  'already': 35,
#  'case': 35,
#  'changing': 35,
#  'country': 35,
#  'develop': 35,
#  'else': 35,
#  'em': 35,
#  'enter': 35,
#  'event': 35,
#  'fights': 35,
#  'fluid': 35,
#  'girl': 35,
#  'important': 35,
#  'instead': 35,
#  'mankind': 35,
#  'meet': 35,
#  'navigate': 35,
#  'plot': 35,
#  'potential': 35,
#  'presentation': 35,
#  'room': 35,
#  'stick': 35,
#  'successful': 35,
#  'via': 35,
#  'working': 35,
#  '50': 34,
#  'Franchise': 34,
#  'Legends': 34,
#  'Modern': 34,
#  'Series': 34,
#  'Story': 34,
#  'anyone': 34,
#  'classes': 34,
#  'club': 34,
#  'complex': 34,
#  'computer': 34,
#  'creating': 34,
#  'criminal': 34,
#  'devastating': 34,
#  'die': 34,
#  'earth': 34,
#  'entirely': 34,
#  'es': 34,
#  'excellent': 34,
#  'experiences': 34,
#  'explosive': 34,
#  'father': 34,
#  'improve': 34,
#  'juego': 34,
#  'league': 34,
#  'leave': 34,
#  'lies': 34,
#  'machines': 34,
#  'retro': 34,
#  'social': 34,
#  'soldiers': 34,
#  'solid': 34,
#  'tough': 34,
#  'type': 34,
#  'B': 33,
#  'John': 33,
#  'NASCAR': 33,
#  'Race': 33,
#  'Some': 33,
#  'US': 33,
#  'Vietnam': 33,
#  'access': 33,
#  'armor': 33,
#  'courses': 33,
#  'decent': 33,
#  'en': 33,
#  'gang': 33,
#  'gods': 33,
#  'gun': 33,
#  'half': 33,
#  'reach': 33,
#  'robots': 33,
#  'rules': 33,
#  'ships': 33,
#  'spend': 33,
#  'terrain': 33,
#  'terrible': 33,
#  'thanks': 33,
#  'thousands': 33,
#  'titles': 33,
#  'today': 33,
#  'twisted': 33,
#  'whose': 33,
#  'Become': 32,
#  'Europe': 32,
#  'He': 32,
#  'Heroes': 32,
#  'London': 32,
#  'Make': 32,
#  'Sean': 32,
#  'Through': 32,
#  'Tour': 32,
#  'abandoned': 32,
#  'book': 32,
#  'bugs': 32,
#  'built': 32,
#  'click': 32,
#  'e': 32,
#  'energy': 32,
#  'fact': 32,
#  'following': 32,
#  'follows': 32,
#  'front': 32,
#  ...}

# %% [markdown]
# 테스트셋 트레이닝셋 분리

# %%
df_train,df_test = train_test_split(df_game_s, random_state = 1557)

# %%
print(df_train.shape,df_test.shape)
# Out:
# (10766, 4) (3589, 4)

# %%
vocab=set(np.hstack(df_game_s['token_summary'].values))

# %%
print(len(vocab))
# Out:
# 46569

# %%
vocab = {tkn: i+2 for i, tkn in enumerate(vocab)}
vocab['<unk>'] = 0
vocab['<pad>'] = 1

# %% [markdown]
# 단어임베딩구하기

# %%
embedding_layer = nn.Embedding(num_embeddings=len(vocab), embedding_dim=50,padding_idx=1)

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 1.3953, -1.4804,  0.5375,  ...,  0.5386,  0.3954,  0.4236],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.3729, -0.2503, -0.7438,  ...,  0.6275, -0.1872, -1.0986],
#         ...,
#         [ 1.2598,  1.0251,  0.9962,  ...,  0.1087, -0.1900,  0.0367],
#         [ 1.0677, -0.3866,  0.1556,  ...,  0.6795,  0.8937,  0.7976],
#         [ 0.6807, -1.1566, -0.6548,  ...,  1.7627,  0.4633, -1.3812]],
#        requires_grad=True)

# %% [markdown]
# vocab_train을 통해 df_train의 summary를 정수인코딩

# %%
df_train['encoding_summary'] = df_train['token_summary'].apply(lambda x: [vocab[item] for item in x])
df_test['encoding_summary'] = df_test['token_summary'].apply(lambda x: [vocab[item] for item in x])

# %% [markdown]
# 단어 개수에 비해 로우가 적음(데이터수의 부족)

# %%
mlen=0
for x in df_game_s.token_summary.values:
    mlen=max(mlen,len(x))
def mypad(x):
  if(len(x)<mlen):
    for y in range(len(x),mlen):
      x.append(1)
  return x
xtrain=df_train['encoding_summary'].apply(mypad)
xtest=df_test['encoding_summary'].apply(mypad)
xtrain=torch.tensor(list(df_train['encoding_summary'].values),dtype=torch.float32,requires_grad=True)
xtest=torch.tensor(list(df_test['encoding_summary'].values),dtype=torch.float32,requires_grad=True)

# %%
ytrain=torch.tensor(list(df_train['userscore'].values),dtype=torch.float32,requires_grad=True)
ytest=torch.tensor(list(df_test['userscore'].values),dtype=torch.float32,requires_grad=True)

# %% [markdown]
# 모델input을 쓰기위해 크기 통일

# %%
print(xtest.shape)
print(xtrain.shape)
print(ytest.shape)
print(ytrain.shape)
# Out:
# torch.Size([3589, 509])
# torch.Size([10766, 509])
# torch.Size([3589])
# torch.Size([10766])

# %%
class word_dataset(data.Dataset):
    def __init__(self, wdata, label):
        self.wdata = wdata
        self.label = label.reshape(label.shape[0],1)
        
    def __len__(self):
        return len(self.wdata)
    
    def __getitem__(self,index):
        return self.wdata[index],self.label[index]
testd=word_dataset(xtest,ytest)
traind=word_dataset(xtrain,ytrain)

# %%
train_loader = torch.utils.data.DataLoader(dataset=traind, batch_size=10, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=testd, batch_size=10, shuffle=False)

# %% [markdown]
# CNN모델만들기

# %%
class Model_1(nn.Module):
    def __init__(self):
        super(Model_1, self).__init__()      
        self.conv1 = nn.Conv2d(1, 9, kernel_size=20, padding=0)
        self.conv2 = nn.Conv2d(9, 16, kernel_size=20, padding=0)
        self.conv3 = nn.Conv2d(16, 2, kernel_size=20, padding=0)
        self.fc1 = nn.Linear(1710, 300)
        self.fc2 = nn.Linear(300,50)
        self.fc3=nn.Linear(50,1)
        self.embedding = nn.Embedding(len(vocab),300)
        self.relu = torch.nn.ReLU()
        for m in self.modules():
            if isinstance(m, nn.Linear):
                torch.nn.init.kaiming_uniform_(m.weight.data, nonlinearity='relu')
            if isinstance(m,nn.Conv2d):
                torch.nn.init.kaiming_uniform_(m.weight.data, nonlinearity='relu')
            if isinstance(m,nn.Embedding):
                torch.nn.init.kaiming_uniform_(m.weight.data, nonlinearity='relu')
    def forward(self,x):
        x=self.embedding(x.long())
        x=x.unsqueeze(1)
        x = self.relu(self.conv1(x))
        x = torch.nn.functional.avg_pool2d(x, kernel_size=4,stride=2)
        x=self.relu(self.conv2(x))
        x= torch.nn.functional.avg_pool2d(x,kernel_size=5,stride=2)
        x=self.relu(self.conv3(x))
        x= torch.nn.functional.avg_pool2d(x,kernel_size=3,stride=2)
        x=torch.flatten(x,1)
        x=self.relu(self.fc1(x))
        x=self.relu(self.fc2(x))
        x=self.relu(self.fc3(x))
        return x

# %%
def training_epoch(train_loader, network, loss_func, optimizer, epoch):
    train_losses = []
    train_correct = 0
    log_interval = 300
    ret=[]
    for batch_idx, (wdata, label) in enumerate(train_loader):
        wdata, label = wdata.to(device), label.to(device)
        # 미분값의 초기화
        optimizer.zero_grad()
        # Forward propagration 계산하기.
        outputs = network(wdata)
        # Cross_entropy 함수를 적용하여 loss를 구하고 저장하기
        loss = loss_func(outputs,label)
        train_losses.append(loss.item())
        # Gradinet 구하기
        loss.backward()
        # weight값 update 하
        optimizer.step()
        # 학습 상황 출력
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.2f}%)]\tLoss: {:.6f}'
                  .format(epoch, batch_idx * len(label), len(train_loader.dataset),100. * batch_idx / len(train_loader),
                          loss.item()))
            
    return train_losses,ret

# %%
def test_epoch(test_loader, network, loss_func, val = False):
    correct = 0
    ret=[]
    test_losses = []
    
    with torch.no_grad():
        for batch_idx, (wdata, label) in enumerate(test_loader):
            wdata, label = wdata.to(device), label.to(device)

            # Forward propagration 계산하기.
            outputs = network(wdata)
            # Cross_entropy 함수를 적용하여 loss를 구하기
            loss = loss_func(outputs,label)
            test_losses.append(loss.item())
            print('Test Loss: {:.6f}'.format(loss.item()))
    return test_losses,ret

# %%
def training(network, learning_rate = 0.001):
    
    epoches = 15
    
    cls_loss = nn.MSELoss()
    optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)
    
    train_losses_per_epoch = []
    test_losses_per_epoch = []
    
    train_accuracies = []
    test_accuracies = []
    ret=[]
    
    for epoch in range(epoches):
                
        # 모델를 학습 중이라고 선언하기
        network.train()
        
        train_losses,temp = training_epoch(train_loader,network,cls_loss,optimizer, epoch)
        ret=temp
        # epoch 별로 loss 평균값, 정확도 구하기
        average_loss = np.mean(train_losses)
        train_losses_per_epoch.append(average_loss)
        
        ### 학습 중에  test 결과 보기
        
        # 모델 test 중인 것을 선언하기
    network.eval()
    with torch.no_grad():
        test_losses,temp2= test_epoch(test_loader, network, cls_loss, False)
        ret.extend(temp2)
    return train_losses_per_epoch, ret

# %%
network = Model_1().to(device)
rlt_const,ret = training(network)
# Out:
# Train Epoch: 0 [0/10766 (0.00%)]	Loss: 43.392162
# Train Epoch: 0 [3000/10766 (27.86%)]	Loss: 1.754289
# Train Epoch: 0 [6000/10766 (55.71%)]	Loss: 1.871616
# Train Epoch: 0 [9000/10766 (83.57%)]	Loss: 3.609795
# Train Epoch: 1 [0/10766 (0.00%)]	Loss: 2.265746
# Train Epoch: 1 [3000/10766 (27.86%)]	Loss: 1.951617
# Train Epoch: 1 [6000/10766 (55.71%)]	Loss: 2.673002
# Train Epoch: 1 [9000/10766 (83.57%)]	Loss: 2.773591
# Train Epoch: 2 [0/10766 (0.00%)]	Loss: 1.224960
# Train Epoch: 2 [3000/10766 (27.86%)]	Loss: 1.139890
# Train Epoch: 2 [6000/10766 (55.71%)]	Loss: 1.103725
# Train Epoch: 2 [9000/10766 (83.57%)]	Loss: 1.870789
# Train Epoch: 3 [0/10766 (0.00%)]	Loss: 0.613843
# Train Epoch: 3 [3000/10766 (27.86%)]	Loss: 1.560860
# Train Epoch: 3 [6000/10766 (55.71%)]	Loss: 0.325993
# Train Epoch: 3 [9000/10766 (83.57%)]	Loss: 1.312669
# Train Epoch: 4 [0/10766 (0.00%)]	Loss: 0.420163
