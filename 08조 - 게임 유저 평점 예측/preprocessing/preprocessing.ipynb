# %% [markdown]
# 전처리

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mplcursors # Use this is for creating a cursor-interactive plot with "%matplotlib notebook"
from sklearn.decomposition import NMF # Use this for training Non-negative Matrix Factorization
from sklearn.utils.extmath import randomized_svd # Use this for training Singular Value Decomposition
from sklearn.manifold import TSNE # Use this for training t-sne manifolding

plt.style.use('ggplot') # You can also use different style

# just for plot checking, use this option
# %matplotlib inline

# for interactive plot
# If you use this option, plot will appear at first-drawn position
# %matplotlib notebook

warnings.filterwarnings('ignore')

# %% [markdown]
# 예제 데이터셋 불러오기
# 데이터셋 출처 https://www.kaggle.com/datasets/deepcontractor/top-video-games-19952021-metacritic
# 데이터셋 1995년부터 2021년까지의 자료
# all_games.csv의 칼럼
# names platform release_date summary(게임 요약) meta_score(전문가 스코어 100점만점) user_review(유저스코어 10점만점)

# %%
dir = './dataset/'
df_games=pd.read_csv(dir+'all_games.csv',usecols=['name','platform','release_date','meta_score','user_review'])

# %% [markdown]
# 게임수 파악
# 6546개의 플랫폼이 다른 동일 게임이 존재

# %%
n_games=len(df_games['name'])
n_game_same_name=len(df_games['name'].unique())
n_games,n_game_same_name,n_games-n_game_same_name
# Out:
# (18800, 12254, 6546)

# %% [markdown]
# 이름이없는 row 존재하지않음

# %%
len(df_games)-n_games
# Out:
# 0

# %% [markdown]
# 칼럼 타입 확인하기

# %%
df_games.dtypes
# Out:
# name            object
# platform        object
# release_date    object
# meta_score       int64
# user_review     object
# dtype: object

# %% [markdown]
# user_review칼럼에서 tbd(미정)값 존재 확인

# %%
df_games.astype({'name':'string','platform':'string','release_date':'string','user_review':'string'})
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score user_review
# 0       November 23, 1998          99         9.1
# 1      September 20, 2000          98         7.4
# 2          April 29, 2008          98         7.7
# 3       September 8, 1999          98         8.4
# 4          April 29, 2008          98         7.9
# ...                   ...         ...         ...
# 18795        May 21, 2013          22         1.3
# 18796    November 3, 2003          22         1.7
# 18797  September 22, 2015          21         2.9
# 18798    October 15, 2012          20         1.7
# 18799      March 31, 2009          20         2.0
#
# [18800 rows x 5 columns]

# %% [markdown]
# user review칼럼에서 tbd값이 포함된 row처리?
#
# 일단 0.0점으로 변경(알고리즘에 따라 달라질듯)

# %%
df_games.loc[df_games.user_review=='tbd','user_review']='0.0'

# %% [markdown]
# tbd값 처리후 데이터타입 float으로 변경

# %%
df_games.astype({'user_review':'float'})
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score  user_review
# 0       November 23, 1998          99          9.1
# 1      September 20, 2000          98          7.4
# 2          April 29, 2008          98          7.7
# 3       September 8, 1999          98          8.4
# 4          April 29, 2008          98          7.9
# ...                   ...         ...          ...
# 18795        May 21, 2013          22          1.3
# 18796    November 3, 2003          22          1.7
# 18797  September 22, 2015          21          2.9
# 18798    October 15, 2012          20          1.7
# 18799      March 31, 2009          20          2.0
#
# [18800 rows x 5 columns]

# %% [markdown]
# 크롤링한 데이터 전처리

# %%
def datecut(x):
    return x[-4:]
dir2="../data/"
pl=["ps4","switch","pc","ps5","xboxone","xbox-series-x"]
df_crawl_game=pd.DataFrame()
for x in pl:
    df_games2=pd.read_csv(dir2+x+'.csv')
    df_games2.loc[df_games2.userscore=='None','userscore']='tbd'
    df_games2.loc[df_games2.userscore=='tbd','userscore']=df_games2.loc[df_games2.userscore!='tbd']['userscore'].astype({'userscore':float}).describe()['mean']
    df_games2=df_games2.astype({'userscore':'float'})   #유저스코어 연속형 데이터로 변경
    df_games2['platform']=x
    print(len(df_games2.loc[df_games2.userscore=='tbd'])) #아직도 tbd값이 존재하는지 확인
    df_crawl_game=pd.concat([df_crawl_game,df_games2])
    df_games2.to_csv(dir2+x+'.csv',sep=',',float_format='%.2f',index=False)
df_crawl_game=df_crawl_game[['title','metascore','userscore','genres','publisher','developer','release_date','summary','rating','platform']]
df_crawl_game['release_date']=df_crawl_game['release_date'].apply(datecut)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# 최종 합쳐진 데이터셋 확인

# %%
df_crawl_game
# Out:
#                                               title  metascore  userscore  \
# 0             Surgeon Simulator: Experience Reality         43       4.40
# 1              Transformers: Rise of the Dark Spark         43       4.20
# 2                                       NBA Live 14         43       2.60
# 3                                          WWE 2K20         43       1.60
# 4                                          VR Karts         42       5.60
# ..                                              ...        ...        ...
# 209                                         Road 96         78       6.70
# 210              WRC 9 FIA World Rally Championship         78       6.00
# 211                                Shadow Warrior 3         78       6.00
# 212  Blast Brigade vs. the Evil Legion of Dr. Cread         78       6.53
# 213             Taiko no Tatsujin: The Drum Master!         78       8.00
#
#                                                 genres           publisher  \
# 0                           Simulation|Virtual|Career|       Bossa Studios
# 1                     Action Adventure|Sci-Fi|General|          Activision
# 2    Arcade|Sports|Traditional|Team|Basketball|Arcade|     Electronic Arts
# 3                  Sports|Individual|Combat|Wrestling|            2K Games
# 4                                 Racing|Arcade|Other|     Viewpoint Games
# ..                                                 ...                 ...
# 209                         Adventure|3D|First-Person|         Merge Games
# 210                      Racing|Simulation|Automobile|               Nacon
# 211                Action|First-Person|Shooter|Arcade|    Devolver Digital
# 212                 Action|Platformer|2D|Metroidvania|            MY.GAMES
# 213                               Action|Rhythm|Music|  Bandai Namco Games
#
#                   developer release_date  \
# 0             Bossa Studios         2016
# 1           Edge of Reality         2014
# 2                 EA Sports         2013
# 3           Visual Concepts         2019
# 4           Viewpoint Games         2017
# ..                      ...          ...
# 209  Digixart Entertainment         2022
# 210               KT Racing         2020
# 211         Flying Wild Hog         2022
# 212      Allods Team Arcade         2022
# 213      Bandai Namco Games         2022
#
#                                                summary rating       platform
# 0    This game is ridiculously fun once you've plac...      T            ps4
# 1    Fight your way through both Earth and Cybertro...      T            ps4
# 2    BounceTek -- Revolutionary physics-based dribb...      E            ps4
# 3    F the haters. This game is still fun.  And it’...      T            ps4
# 4    The checkered flag is about to drop on a new V...      E            ps4
# ..                                                 ...    ...            ...
# 209  <span class="blurb blurb_collapsed">Summer 199...      T  xbox-series-x
# 210  <span class="blurb blurb_collapsed">The game r...      E  xbox-series-x
# 211  Shadow Warrior 3 launches the offbeat first-pe...   None  xbox-series-x
# 212  <span class="blurb blurb_collapsed">Blast Brig...   E10+  xbox-series-x
# 213  <span class="blurb blurb_collapsed">The same f...      T  xbox-series-x
#
# [14355 rows x 10 columns]

# %% [markdown]
# summary칼럼에 태그가 남아있는문제

# %%
df_crawl_game['summary']=df_crawl_game['summary'].str.replace(pat=r'<[^>]*>',repl=r' ',regex=True)

# %%
df_crawl_game
# Out:
#                                               title  metascore  userscore  \
# 0             Surgeon Simulator: Experience Reality         43       4.40
# 1              Transformers: Rise of the Dark Spark         43       4.20
# 2                                       NBA Live 14         43       2.60
# 3                                          WWE 2K20         43       1.60
# 4                                          VR Karts         42       5.60
# ..                                              ...        ...        ...
# 209                                         Road 96         78       6.70
# 210              WRC 9 FIA World Rally Championship         78       6.00
# 211                                Shadow Warrior 3         78       6.00
# 212  Blast Brigade vs. the Evil Legion of Dr. Cread         78       6.53
# 213             Taiko no Tatsujin: The Drum Master!         78       8.00
#
#                                                 genres           publisher  \
# 0                           Simulation|Virtual|Career|       Bossa Studios
# 1                     Action Adventure|Sci-Fi|General|          Activision
# 2    Arcade|Sports|Traditional|Team|Basketball|Arcade|     Electronic Arts
# 3                  Sports|Individual|Combat|Wrestling|            2K Games
# 4                                 Racing|Arcade|Other|     Viewpoint Games
# ..                                                 ...                 ...
# 209                         Adventure|3D|First-Person|         Merge Games
# 210                      Racing|Simulation|Automobile|               Nacon
# 211                Action|First-Person|Shooter|Arcade|    Devolver Digital
# 212                 Action|Platformer|2D|Metroidvania|            MY.GAMES
# 213                               Action|Rhythm|Music|  Bandai Namco Games
#
#                   developer release_date  \
# 0             Bossa Studios         2016
# 1           Edge of Reality         2014
# 2                 EA Sports         2013
# 3           Visual Concepts         2019
# 4           Viewpoint Games         2017
# ..                      ...          ...
# 209  Digixart Entertainment         2022
# 210               KT Racing         2020
# 211         Flying Wild Hog         2022
# 212      Allods Team Arcade         2022
# 213      Bandai Namco Games         2022
#
#                                                summary rating       platform
# 0    This game is ridiculously fun once you've plac...      T            ps4
# 1    Fight your way through both Earth and Cybertro...      T            ps4
# 2    BounceTek -- Revolutionary physics-based dribb...      E            ps4
# 3    F the haters. This game is still fun.  And it’...      T            ps4
# 4    The checkered flag is about to drop on a new V...      E            ps4
# ..                                                 ...    ...            ...
# 209   Summer 1996. Today is the day! You hit the ro...      T  xbox-series-x
# 210   The game runs nicely 60fps xbox series S- The...      E  xbox-series-x
# 211  Shadow Warrior 3 launches the offbeat first-pe...   None  xbox-series-x
# 212   Blast Brigade vs. The Evil Legion of Dr. Crea...   E10+  xbox-series-x
# 213   The same fun drumming game you know and love....      T  xbox-series-x
#
# [14355 rows x 10 columns]

# %% [markdown]
# 특수문자제거

# %%
df_crawl_game['summary']= df_crawl_game['summary'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
df_crawl_game
# Out:
#                                               title  metascore  userscore  \
# 0             Surgeon Simulator: Experience Reality         43       4.40
# 1              Transformers: Rise of the Dark Spark         43       4.20
# 2                                       NBA Live 14         43       2.60
# 3                                          WWE 2K20         43       1.60
# 4                                          VR Karts         42       5.60
# ..                                              ...        ...        ...
# 209                                         Road 96         78       6.70
# 210              WRC 9 FIA World Rally Championship         78       6.00
# 211                                Shadow Warrior 3         78       6.00
# 212  Blast Brigade vs. the Evil Legion of Dr. Cread         78       6.53
# 213             Taiko no Tatsujin: The Drum Master!         78       8.00
#
#                                                 genres           publisher  \
# 0                           Simulation|Virtual|Career|       Bossa Studios
# 1                     Action Adventure|Sci-Fi|General|          Activision
# 2    Arcade|Sports|Traditional|Team|Basketball|Arcade|     Electronic Arts
# 3                  Sports|Individual|Combat|Wrestling|            2K Games
# 4                                 Racing|Arcade|Other|     Viewpoint Games
# ..                                                 ...                 ...
# 209                         Adventure|3D|First-Person|         Merge Games
# 210                      Racing|Simulation|Automobile|               Nacon
# 211                Action|First-Person|Shooter|Arcade|    Devolver Digital
# 212                 Action|Platformer|2D|Metroidvania|            MY.GAMES
# 213                               Action|Rhythm|Music|  Bandai Namco Games
#
#                   developer release_date  \
# 0             Bossa Studios         2016
# 1           Edge of Reality         2014
# 2                 EA Sports         2013
# 3           Visual Concepts         2019
# 4           Viewpoint Games         2017
# ..                      ...          ...
# 209  Digixart Entertainment         2022
# 210               KT Racing         2020
# 211         Flying Wild Hog         2022
# 212      Allods Team Arcade         2022
# 213      Bandai Namco Games         2022
#
#                                                summary rating       platform
# 0    This game is ridiculously fun once you ve plac...      T            ps4
# 1    Fight your way through both Earth and Cybertro...      T            ps4
# 2    BounceTek    Revolutionary physics based dribb...      E            ps4
# 3    F the haters  This game is still fun   And it ...      T            ps4
# 4    The checkered flag is about to drop on a new V...      E            ps4
# ..                                                 ...    ...            ...
# 209   Summer 1996  Today is the day  You hit the ro...      T  xbox-series-x
# 210   The game runs nicely 60fps xbox series S  The...      E  xbox-series-x
# 211  Shadow Warrior 3 launches the offbeat first pe...   None  xbox-series-x
# 212   Blast Brigade vs  The Evil Legion of Dr  Crea...   E10+  xbox-series-x
# 213   The same fun drumming game you know and love ...      T  xbox-series-x
#
# [14355 rows x 10 columns]

# %%
df_crawl_game.to_csv(dir2+'all_game.csv',sep=',',float_format='%.2f',index=False)
